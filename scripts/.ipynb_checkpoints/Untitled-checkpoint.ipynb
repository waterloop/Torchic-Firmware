# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
df = pd.read_csv("./temp_data.csv")
display(df)
# Out:
#       T     R
# 0   -40   340
# 1   -30   391
# 2   -20   424
# 3   -10   460
# 4     0   498
# 5    10   538
# 6    20   581
# 7    25   603
# 8    30   626
# 9    40   672
# 10   50   722
# 11   60   773
# 12   70   826
# 13   80   882
# 14   90   940
# 15  100  1000
# 16  110  1062
# 17  120  1127
# 18  130  1194
# 19  140  1262
# 20  150  1334
# 21  160  1407
# 22  170  1482
# 23  180  1560
# 24  190  1640
# 25  200  1722
# 26  210  1807
# 27  220  1893
# 28  230  1982
# 29  240  2073
# 30  250  2166
# 31  260  2261
# 32  270  2357
# 33  290  2452
# 34  300  2624

# %%
# %matplotlib widget

R = df["R"].to_numpy()
T = df["T"].to_numpy()

coeffs = np.polyfit(R, T, 4)
coeffs = np.flip(coeffs)
display(coeffs)

def reg_eq(r):
    ret = 0
    for i, c in enumerate(coeffs):
        ret += c*(r**i)
    return ret

plt.close()
plt.scatter(R, T)
plt.plot(R, [reg_eq(r) for r in R])
plt.show()
# Out:
# array([ 1.56911274e+04, -2.39706306e+02,  1.64091646e+00, -6.72238970e-03,
#         1.84793949e-05, -3.61521655e-08,  5.20597083e-11, -5.62570810e-14,
#         4.60515207e-17, -2.85907728e-20,  1.33684396e-23, -4.62854203e-27,
#         1.14995334e-30, -1.93755708e-34,  1.98169644e-38, -9.28392570e-43])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
